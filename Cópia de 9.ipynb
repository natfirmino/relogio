# %%
 
a = int(input("Digite o primeiro valor:"))
b = int(input("Digite o segundo valor:"))
c = int(input("Digite o terceiro valor:"))
if a > b and a > c:
   maior = a
   print("o número maior é ", maior)
if b > a and b > c:
    maior = b
    print("o número maior é ", maior)
if c > a and c > b:
    maior = c
    print("o número maior é", maior)
# Out:
# Digite o primeiro valor:1200
# Digite o segundo valor:2000
# Digite o terceiro valor:100
# o número maior é  2000
